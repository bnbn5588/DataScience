# %% [markdown]
# <a href="https://colab.research.google.com/github/EdwardYeung6/Jupyter-Notebook-Partice/blob/main/DataScienceEcosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Tools and Ecosystem
# ![2-title.png](data:image/png;base64,...)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
# * Identify popular data science languages
# * Identify commonly used data science libraries
# * Outline chart design functions in Jupyter Notebook
# * Arithmetic expression using Python

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. NumPy
# 2. Pandas
# 2. TensorFlow

# %% [markdown]
# | Data Scinece Tools|
# ------------------------
# |Apache Spark|
# |Jupyter Notbook|
# |R Studio|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60
hours = 200/60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Nonthpat Wongkham
